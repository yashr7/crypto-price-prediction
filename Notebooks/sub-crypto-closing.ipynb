# %% [markdown]
# # DMA COURSE PROJECT
# ### 5th Sem, CSE
# ### Team 07
# |             NAME            	|          USN        	|
# |:---------------------------:	|:-------------------:	|
# |         Arpit   Arora       	|     01FE19BCS232    	|
# |          Yash   Raj         	|     01FE19BCS229    	|
# |     Sivanand   Mahapatra    	|     01FE19BCS230    	|
# |        Nitish   Kumar       	|     01FE19BCS227    	|
# |           Nihad   J         	|     01FE19BCS260    	|
#
#
# ## 5DMACP05 - Cryptocurrency Closing Price Prediction Challenge
#
#
#
#
# ## 1. Problem Statement
#
# > After the boom and bust of cryptocurrencies’ prices in recent years, cryptocurrencies have been increasingly regarded as an investment asset. Because of their highly volatile nature, there is a need for good predictions on which to base investment decisions. Different existing studies have leveraged machine learning for more accurate cryptocurrency price prediction. We are interested in applying different modeling techniques to samples with different data structures (qualitative and quantitative data) and dimensional features to achieve an optimization in price prediction.
#
#
# ## 2. Data
#
# [Dataset from Zindi](https://zindi.africa/competitions/cryptocurrency-closing-price-prediction/data),
#
# There are 3 datasets:
# 1. **Train.csv** - contains the target. This is the dataset that you will use to train your model..
# 2. **Test.csv** - resembles Train.csv but without the target-related columns. This is the dataset on which you will apply your model to..
# 3. **SampleSubmission.csv** - shows the submission format for this competition, with the ‘id’ column mirroring that of Test.csv and the close column containing your predictions.
#
# ## 3. Evaluation
#
# For this problem, our main goal is to reach and exceed a given threshold (a specified RMSE score) in the final developed model.
#
# To see how well our model is doing, we'll calculate the RMSE and then compare our results to others on the [Zindi leaderboard](https://zindi.africa/competitions/cryptocurrency-closing-price-prediction/leaderboard).
#
# ## 4. Features
#
# For this dataset, Zindi provided a [data dictionary](https://zindi.africa/competitions/cryptocurrency-closing-price-prediction/data)  which contains information about what each attribute of the dataset means.
#
# The target value is the closing price. We have data extracted in an interval of 1h for a period of one year (from 1st of March 2020 to 1st of March 2021).

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Loading datasets

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')
ss = pd.read_csv('SampleSubmission.csv')

# %% [markdown]
# ### Exploring the data

# %%
test.head()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Looking for missing values

# %%
# ax = train.isna().sum().sort_values().plot(kind = 'barh', figsize = (9, 10))
# plt.title('Percentage of Missing Values Per Column in Train Set', fontdict={'size':15})
# for p in ax.patches:
#     percentage ='{:,.0f}%'.format((p.get_width()/train.shape[0])*100)
#     width, height =p.get_width(),p.get_height()
#     x=p.get_x()+width+0.02
#     y=p.get_y()+height/2
#     ax.annotate(percentage,(x,y))

# %%
# ax = test.isna().sum().sort_values().plot(kind = 'barh', figsize = (9, 10))
# plt.title('Percentage of Missing Values Per Column in Test Set', fontdict={'size':15})

# for p in ax.patches:
#     percentage ='{:,.1f}%'.format((p.get_width()/test.shape[0])*100)
#     width, height =p.get_width(),p.get_height()
#     x=p.get_x()+width+0.02
#     y=p.get_y()+height/2
#     ax.annotate(percentage,(x,y))

# %% [markdown]
# ### Correlation analysis

# %%
# train.corr()['close'].sort_values(ascending=False)

# %%
# train.isnull().sum()

# %% [markdown]
# #### Dropping rows where entries of most important columns are missing

# %%
newTest=newTest[newTest.isnull().any(axis=1)]

# %%
newTest=newTest.fillna(0)

# %%
newTest

# %%
newTest.to_csv("nullRows.csv")

# %%
# list of relevant columns to keep

useful = ['id', 'open']
drop = []
for x in list(test.columns):
  if x not in useful:
    drop.append(x)


# dropping irrelevant columns in test set

newTest = test.drop(labels = drop,
          axis = 1)

# %%
test

# %%
# train.dropna(axis=0,
#           subset = ['open', 'market_cap', 'market_cap_global', 'volatility', 'percent_change_24h', 'volume'],
#           inplace = True)
# test.dropna(axis=0,
#           subset = ['open'],
#           inplace = True)

# %% [markdown]
# #### Checking for remaining null values

# %%
# test.info()

# %% [markdown]
# #### Removing columns with percentage of missing values > 60

# %%
train.drop(['medium', 'youtube'], axis=1,inplace=True)
train.head()
# Out:
#           id  asset_id          open          high           low  \
# 0  ID_322qz6         1   9422.849081   9428.490628   9422.849081
# 1  ID_3239o9         1   7985.359278   7992.059917   7967.567267
# 2  ID_323J9k         1  49202.033778  49394.593518  49068.057046
# 3  ID_323y5P         1           NaN           NaN           NaN
# 4  ID_324kJH         1  10535.737119  10535.737119  10384.798216
#
#          volume    market_cap  url_shares  unique_url_shares  reddit_posts  \
# 0  7.131986e+08  1.737635e+11      1689.0              817.0          55.0
# 1  4.004755e+08  1.426942e+11       920.0              544.0          20.0
# 2  3.017729e+09  9.166977e+11      1446.0              975.0          72.0
# 3           NaN           NaN         NaN                NaN          17.0
# 4  1.150053e+09  1.921183e+11      1012.0              638.0          24.0
#
#    ...  volatility  market_cap_rank  percent_change_24h_rank  volume_24h_rank  \
# 0  ...    0.007118              1.0                    606.0              2.0
# 1  ...    0.009419              1.0                      NaN              NaN
# 2  ...    0.013530              1.0                    692.0              3.0
# 3  ...         NaN              NaN                      NaN              NaN
# 4  ...    0.010332              1.0                    749.0              2.0
#
#    social_volume_24h_rank  social_score_24h_rank  social_volume  \
# 0                     1.0                    1.0           4422
# 1                     NaN                    NaN           2159
# 2                     1.0                    1.0          10602
# 3                     NaN                    NaN            285
# 4                     1.0                    1.0           3996
#
#    percent_change_24h  market_cap_global         close
# 0            1.434516       2.818066e+11   9428.279323
# 1           -2.459507       2.126897e+11   7967.567267
# 2            4.942448       1.530712e+12  49120.738484
# 3                 NaN                NaN           NaN
# 4            2.609576       3.386925e+11  10384.798216
#
# [5 rows x 47 columns]

# %%
test.drop(['medium', 'youtube'], axis=1,inplace=True)
test.head()
# Out:
#           id  asset_id          open          high           low  \
# 0  ID_323Sn2         1           NaN           NaN           NaN
# 1  ID_325SNW         1  11335.062190  11351.690960  11335.062190
# 2  ID_325uzE         1   6322.560756   6328.362354   6294.714484
# 3  ID_328qCx         1           NaN           NaN           NaN
# 4  ID_3293uJ         1           NaN           NaN           NaN
#
#          volume    market_cap  url_shares  unique_url_shares  reddit_posts  \
# 0           NaN           NaN         NaN                NaN           7.0
# 1  1.064152e+09  2.101460e+11      1664.0             1045.0          64.0
# 2  1.516268e+09  1.153860e+11       397.0              255.0          11.0
# 3           NaN           NaN         NaN                NaN           8.0
# 4           NaN           NaN         NaN                NaN          26.0
#
#    ...  galaxy_score  volatility  market_cap_rank  percent_change_24h_rank  \
# 0  ...           NaN         NaN              NaN                      NaN
# 1  ...          65.5    0.004407              1.0                    711.0
# 2  ...          65.5    0.024035              1.0                    715.0
# 3  ...           NaN         NaN              NaN                      NaN
# 4  ...           NaN         NaN              NaN                      NaN
#
#    volume_24h_rank  social_volume_24h_rank  social_score_24h_rank  \
# 0              NaN                     NaN                    NaN
# 1              2.0                     1.0                    1.0
# 2              2.0                     1.0                    1.0
# 3              NaN                     NaN                    NaN
# 4              NaN                     NaN                    NaN
#
#    social_volume  percent_change_24h  market_cap_global
# 0              9                 NaN                NaN
# 1           7245           -0.555698       3.631050e+11
# 2           2702            1.689370       1.771070e+11
# 3            225                 NaN                NaN
# 4             59                 NaN                NaN
#
# [5 rows x 46 columns]

# %% [markdown]
# #### Removing columns which are barely useful

# %%
# list of relevant columns to keep

useful = ['id', 'open', 'high', 'low', 'volume', 'market_cap', 'social_score',
          'average_sentiment', 'price_score', 'social_impact_score',
          'correlation_rank', 'volatility', 'market_cap_global',
          'percent_change_24h', 'close']

# appending relevant columns to an empty list
drop = []
for x in list(train.columns):
  if x not in useful:
    drop.append(x)

train.drop(labels= drop,
        axis = 1,
        inplace = True)
train.head()
# Out:
#           id          open          high           low        volume  \
# 0  ID_322qz6   9422.849081   9428.490628   9422.849081  7.131986e+08
# 1  ID_3239o9   7985.359278   7992.059917   7967.567267  4.004755e+08
# 2  ID_323J9k  49202.033778  49394.593518  49068.057046  3.017729e+09
# 3  ID_323y5P           NaN           NaN           NaN           NaN
# 4  ID_324kJH  10535.737119  10535.737119  10384.798216  1.150053e+09
#
#      market_cap  social_score  average_sentiment  price_score  \
# 0  1.737635e+11    11681999.0                3.6          2.7
# 1  1.426942e+11     5924770.0                3.7          2.0
# 2  9.166977e+11    47796942.0                3.7          3.1
# 3           NaN           NaN                NaN          NaN
# 4  1.921183e+11    14426405.0                3.7          4.7
#
#    social_impact_score  correlation_rank  volatility  percent_change_24h  \
# 0                  3.6               3.3    0.007118            1.434516
# 1                  2.0               1.0    0.009419           -2.459507
# 2                  3.0               3.3    0.013530            4.942448
# 3                  NaN               NaN         NaN                 NaN
# 4                  3.8               4.4    0.010332            2.609576
#
#    market_cap_global         close
# 0       2.818066e+11   9428.279323
# 1       2.126897e+11   7967.567267
# 2       1.530712e+12  49120.738484
# 3                NaN           NaN
# 4       3.386925e+11  10384.798216

# %%
drop = []
for x in list(test.columns):
  if x not in useful:
    drop.append(x)


# dropping irrelevant columns in test set

test.drop(labels = drop,
          axis = 1,
          inplace = True)

test.head()
# Out:
#           id          open          high           low        volume  \
# 0  ID_323Sn2           NaN           NaN           NaN           NaN
# 1  ID_325SNW  11335.062190  11351.690960  11335.062190  1.064152e+09
# 2  ID_325uzE   6322.560756   6328.362354   6294.714484  1.516268e+09
# 3  ID_328qCx           NaN           NaN           NaN           NaN
# 4  ID_3293uJ           NaN           NaN           NaN           NaN
#
#      market_cap  social_score  average_sentiment  price_score  \
# 0           NaN           NaN                NaN          NaN
# 1  2.101460e+11    23465365.0                3.7          3.2
# 2  1.153860e+11     3832828.0                3.7          3.0
# 3           NaN           NaN                NaN          NaN
# 4           NaN           NaN                NaN          NaN
#
#    social_impact_score  correlation_rank  volatility  percent_change_24h  \
# 0                  NaN               NaN         NaN                 NaN
# 1                  3.4               2.8    0.004407           -0.555698
# 2                  3.0               3.4    0.024035            1.689370
# 3                  NaN               NaN         NaN                 NaN
# 4                  NaN               NaN         NaN                 NaN
#
#    market_cap_global
# 0                NaN
# 1       3.631050e+11
# 2       1.771070e+11
# 3                NaN
# 4                NaN

# %%
train.shape, test.shape
# Out:
# ((12632, 47), (6222, 46))

# %%
train=train.fillna(0)

# %%
test=test.fillna(0)

# %%
test.isnull().sum()
# Out:
# id                         0
# asset_id                   0
# open                       0
# high                       0
# low                        0
# volume                     0
# market_cap                 0
# url_shares                 0
# unique_url_shares          0
# reddit_posts               0
# reddit_posts_score         0
# reddit_comments            0
# reddit_comments_score      0
# tweets                     0
# tweet_spam                 0
# tweet_followers            0
# tweet_quotes               0
# tweet_retweets             0
# tweet_replies              0
# tweet_favorites            0
# tweet_sentiment1           0
# tweet_sentiment2           0
# tweet_sentiment3           0
# tweet_sentiment4           0
# tweet_sentiment5           0
# tweet_sentiment_impact1    0
# tweet_sentiment_impact2    0
# tweet_sentiment_impact3    0
# tweet_sentiment_impact4    0
# tweet_sentiment_impact5    0
# social_score               0
# average_sentiment          0
# news                       0
# price_score                0
# social_impact_score        0
# correlation_rank           0
# galaxy_score               0
# volatility                 0
# market_cap_rank            0
# percent_change_24h_rank    0
# volume_24h_rank            0
# social_volume_24h_rank     0
# social_score_24h_rank      0
# social_volume              0
# percent_change_24h         0
# market_cap_global          0
# dtype: int64

# %%
# train.to_csv("train_v1.csv")

# %% [markdown]
# ## Data Visualisation

# %%
# plt.figure(figsize=(12,6))
# sns.histplot(data=train,x="close", bins=20)

# %%
# plt.figure(figsize=(12,6))
# sns.lineplot(x='market_cap_global',y='close',data=train)

# %%
# plt.figure(figsize=(12,6))
# sns.lineplot(x='open',y='close',data=train)

# %%
# plt.figure(figsize=(12,6))
# sns.scatterplot(x='tweet_spam',y='close',data=train)

# %%
# sns.pairplot(train)

# %%
# plt.figure(figsize=(15,10))
# sns.heatmap(train.corr())

# %% [markdown]
# ## Learning Models

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# #### X and y arrays

# %%
# Creating the X and y variables

X = train.drop(['id','close'], axis=1)
y = train['close']

# features
features = list(X.columns)
X_test = test.drop(['id'], axis=1)
y_train = y

# %%
y_train
X_test
# Out:
#       asset_id          open          high           low        volume  \
# 0            1      0.000000      0.000000      0.000000  0.000000e+00
# 1            1  11335.062190  11351.690960  11335.062190  1.064152e+09
# 2            1   6322.560756   6328.362354   6294.714484  1.516268e+09
# 3            1      0.000000      0.000000      0.000000  0.000000e+00
# 4            1      0.000000      0.000000      0.000000  0.000000e+00
# ...        ...           ...           ...           ...           ...
# 6217         1   8266.942912   8266.942912   8259.796103  3.100637e+08
# 6218         1  10869.612770  10873.493490  10865.827630  6.989360e+08
# 6219         1      0.000000      0.000000      0.000000  0.000000e+00
# 6220         1      0.000000      0.000000      0.000000  0.000000e+00
# 6221         1   7058.172796   7078.973345   7052.332304  4.730933e+08
#
#         market_cap  url_shares  unique_url_shares  reddit_posts  \
# 0     0.000000e+00         0.0                0.0           7.0
# 1     2.101460e+11      1664.0             1045.0          64.0
# 2     1.153860e+11       397.0              255.0          11.0
# 3     0.000000e+00         0.0                0.0           8.0
# 4     0.000000e+00         0.0                0.0          26.0
# ...            ...         ...                ...           ...
# 6217  1.491230e+11       618.0              438.0          15.0
# 6218  2.011600e+11      1608.0              911.0          84.0
# 6219  0.000000e+00         0.0                0.0           8.0
# 6220  0.000000e+00         0.0                0.0           6.0
# 6221  1.275510e+11       954.0              672.0          20.0
#
#       reddit_posts_score  ...  galaxy_score  volatility  market_cap_rank  \
# 0                   56.0  ...           0.0    0.000000              0.0
# 1                  213.0  ...          65.5    0.004407              1.0
# 2                   72.0  ...          65.5    0.024035              1.0
# 3                   96.0  ...           0.0    0.000000              0.0
# 4                   49.0  ...           0.0    0.000000              0.0
# ...                  ...  ...           ...         ...              ...
# 6217               202.0  ...          61.5    0.007076              1.0
# 6218               204.0  ...          67.5    0.005486              1.0
# 6219               139.0  ...           0.0    0.000000              0.0
# 6220                85.0  ...           0.0    0.000000              0.0
# 6221               110.0  ...          62.5    0.012064              1.0
#
#       percent_change_24h_rank  volume_24h_rank  social_volume_24h_rank  \
# 0                         0.0              0.0                     0.0
# 1                       711.0              2.0                     1.0
# 2                       715.0              2.0                     1.0
# 3                         0.0              0.0                     0.0
# 4                         0.0              0.0                     0.0
# ...                       ...              ...                     ...
# 6217                    921.0              2.0                     1.0
# 6218                    807.0              2.0                     1.0
# 6219                      0.0              0.0                     0.0
# 6220                      0.0              0.0                     0.0
# 6221                    858.0              2.0                     1.0
#
#       social_score_24h_rank  social_volume  percent_change_24h  \
# 0                       0.0              9            0.000000
# 1                       1.0           7245           -0.555698
# 2                       1.0           2702            1.689370
# 3                       0.0            225            0.000000
# 4                       0.0             59            0.000000
# ...                     ...            ...                 ...
# 6217                    1.0           1494           -0.967973
# 6218                    1.0           7065            0.000000
# 6219                    0.0            175            0.000000
# 6220                    0.0              6            0.000000
# 6221                    1.0           3469           -3.289226
#
#       market_cap_global
# 0          0.000000e+00
# 1          3.631050e+11
# 2          1.771070e+11
# 3          0.000000e+00
# 4          0.000000e+00
# ...                 ...
# 6217       2.262120e+11
# 6218       3.523270e+11
# 6219       0.000000e+00
# 6220       0.000000e+00
# 6221       1.926560e+11
#
# [6222 rows x 45 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Standardization

# %%
# Instantiate standard scaler

scaler = StandardScaler()

# transform data
X = scaler.fit_transform(X)
X_test = scaler.fit_transform(X_test)
X_test
# Out:
# array([[ 0.        , -0.77478965, -0.77341433, ..., -0.80000528,
#         -0.0704392 , -0.70841292],
#        [ 0.        ,  0.06855475,  0.06690429, ...,  0.6890067 ,
#         -0.25684646,  0.14674036],
#        [ 0.        , -0.30438233, -0.3049519 , ..., -0.24584425,
#          0.49625449, -0.29130593],
#        ...,
#        [ 0.        , -0.77478965, -0.77341433, ..., -0.76584608,
#         -0.0704392 , -0.70841292],
#        [ 0.        , -0.77478965, -0.77341433, ..., -0.80062262,
#         -0.0704392 , -0.70841292],
#        [ 0.        , -0.24965177, -0.24938728, ..., -0.08801227,
#         -1.17379964, -0.25468628]])

# %% [markdown]
# #### Train Test Split

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# #### Creating and Training the Model

# %%
lm = LinearRegression()

# %%
lm.fit(X,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 10578.469774141226

# %%
lm.coef_
# Out:
# array([ 1.41937568e-14, -7.62055082e+03,  1.25451105e+04,  8.78163393e+03,
#         5.83162734e-01, -9.58606242e+01, -5.27459663e+00,  4.35356752e+00,
#         3.80400598e+00, -1.72222548e+00, -1.49511599e-01,  1.04333608e-01,
#         3.22424845e+01,  1.44833102e+00, -4.48661285e+00, -8.05292463e-01,
#        -2.47737995e-01,  2.62685071e+00, -2.84867804e+00, -3.41292560e+00,
#        -1.53579186e+00, -4.31307177e+00, -4.70867160e+01, -5.49093950e+00,
#        -7.23552830e-01,  1.17069042e+00,  2.67741196e+00, -3.78012764e+00,
#         4.34574723e+00, -4.94057833e-01,  1.10412634e+01, -1.44411016e+00,
#        -3.75330818e+00, -3.96276346e+00, -6.27100778e+00,  9.66230953e+00,
#        -3.20202046e+00, -3.00458197e+00,  1.02903403e+00, -4.02072341e+00,
#         4.11408042e-01,  3.08619353e+00,  3.02908662e+01,  2.26297071e+00,
#         9.44908770e+01])

# %%
X_test
# Out:
# array([[ 0.        , -0.77478965, -0.77341433, ..., -0.80000528,
#         -0.0704392 , -0.70841292],
#        [ 0.        ,  0.06855475,  0.06690429, ...,  0.6890067 ,
#         -0.25684646,  0.14674036],
#        [ 0.        , -0.30438233, -0.3049519 , ..., -0.24584425,
#          0.49625449, -0.29130593],
#        ...,
#        [ 0.        , -0.77478965, -0.77341433, ..., -0.76584608,
#         -0.0704392 , -0.70841292],
#        [ 0.        , -0.77478965, -0.77341433, ..., -0.80062262,
#         -0.0704392 , -0.70841292],
#        [ 0.        , -0.24965177, -0.24938728, ..., -0.08801227,
#         -1.17379964, -0.25468628]])

# %% [markdown]
# # Predicting values using LinearRegression model

# %%
predictions = lm.predict(X_test)
predictions
pred = pd.DataFrame({'open': test['open'], 'close': predictions})
pred = pred['close']
pred
# Out:
# 0         -45.040180
# 1       11543.328096
# 2        6391.059429
# 3         -43.990152
# 4         -42.385687
#             ...
# 6217     8380.207578
# 6218    11050.689456
# 6219      -44.301191
# 6220      -45.239398
# 6221     7170.376285
# Name: close, Length: 6222, dtype: float64

# %%
##Scatterplot of real values in train.csv dataset vs predicted values

# plt.scatter(y_test,predictions)
# plt.xlabel('Y Test')
# plt.ylabel('Predicted Y')

# %%
# sns.distplot((y_test-predictions));

# %% [markdown]
# Evaluating model Performance

# %%
# from sklearn import metrics

# print('MAE:', metrics.mean_absolute_error(y_test, predictions))
# print('MSE:', metrics.mean_squared_error(y_test, predictions))
# print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %% [markdown]
# # Using Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
#Fitting the polynomial features to the X_train and X_test

poly_features = PolynomialFeatures(degree = 2)
X_poly_train= poly_features.fit_transform(X)
X_poly_test = poly_features.transform(X_test)

# %%
# Training the model
poly_reg = LinearRegression()
poly_reg.fit(X_poly_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions
poly_ypred = poly_reg.predict(X_poly_test)
poly_ypred

pred = pd.DataFrame({'open': test['open'], 'close': poly_ypred})
predNew = pred['close']
predNew
# Out:
# 0      -4.865325e+06
# 1      -3.050309e+06
# 2       1.759789e+06
# 3      -6.612760e+06
# 4      -4.862112e+06
#             ...
# 6217    4.129689e+06
# 6218   -7.617525e+06
# 6219   -6.410658e+06
# 6220   -4.811648e+06
# 6221   -4.622931e+06
# Name: close, Length: 6222, dtype: float64

# %%
# test=test.reset_index()

# %%
# test= test.drop('index', axis=1)

# %%
# test = test.drop('level_0', axis=1)
# test

# %%
sub=test.join(pred)
sub.rename(columns = {0:'close'}, inplace = True)
sub.head()
sub1=sub[['id','close']]
sub1.head()
sub1.to_csv('sub6_linear.csv', index=False)

# %%
# Out:
# Empty DataFrame
# Columns: [id, close]
# Index: []

# %%
sub2=sub[['id','close']]

# %%
newTest.rename({'open': 'close'}, axis=1, inplace=True)

# %%
newTest

# %%
sub3.isna().sum()

# %%
sub3=sub3.fillna(0)

# %%
sub3=pd.concat([newTest, sub2], axis=0).sort_index()

# %%
sub3.to_csv('sub2_poly.csv', index=False)
sub3

# %%
newTest

# %%
sub2

# %%
pred = pd.DataFrame({'Open': test['open'], 'Close': sub['close']})
pred
# Out:
#               Open         Close
# 0         0.000000    -40.195552
# 1     11335.062190  11528.169754
# 2      6322.560756   6400.157024
# 3         0.000000    -40.195552
# 4         0.000000    -40.195552
# ...            ...           ...
# 6217   8266.942912   8384.971173
# 6218  10869.612770  11034.554431
# 6219      0.000000    -40.195552
# 6220      0.000000    -40.195552
# 6221   7058.172796   7163.793620
#
# [6222 rows x 2 columns]

# %%
# Scatterplot of predicted values vs Actual values

plt.scatter(sub['open'],sub['close'])
plt.xlabel('Open')
plt.ylabel('Close')

# %%
# sns.distplot((y_test-poly_ypred));

# %%
# Measuring the accuracy of the model

print("The RMSE score for the polynomial model : ", np.sqrt(metrics.mean_squared_error(y_test, poly_ypred)))

# %% [markdown]
# # Using RandomForest Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiate model with 1000 decision trees
rf_model  =  RandomForestRegressor(n_estimators=1000, random_state=42)

# Train the model

rf_model  =  rf_model.fit(X_train, y_train)

# %%
# Making predictions based on the trained model 

rf_ypred = rf_model.predict(X_test)

pred = pd.DataFrame({'Actual': y_test, 'Predicted': rf_ypred})
pred

# %%
# Scatterplot of predicted values vs Actual values

plt.scatter(y_test,rf_ypred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')

# %%
sns.distplot((y_test- rf_ypred));

# %%
# Measuring the accuracy of the model

print("The RMSE score for the RandomForest model : ", np.sqrt(metrics.mean_squared_error(y_test, rf_ypred)))
